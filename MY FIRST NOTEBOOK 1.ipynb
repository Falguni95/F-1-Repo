# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print("Hi guys!my name if Falguni Patra,how are you doing?")
# Out:
# Hi guys!my name if Falguni Patra,how are you doing?

# %%
print('here i am using single quotes')
# Out:
# here i am using single quotes

# %%
x=10
y=5
print(x+y)
# Out:
# 15

# %%
print(x*y)
# Out:
# 50

# %%
print(x/y)
# Out:
# 2.0

# %%
print('sum of x and y=', x+y)
# Out:
# sum of x and y= 15

# %%
print('x-y=', x-y)
# Out:
# x-y= 5

# %%
print('the value of x and y are', x,'and', y,'respectively.')
# Out:
# the value of x and y are 10 and 5 respectively.

# %%
print('the multiply of x and y =', x*y)
# Out:
# the multiply of x and y = 50
